# %%
from functions import *

# %% [markdown]
# ## 1. Classical optimization methods
# **A. Implement in Python a continuous hill climber method for single objective minimization problems**

# %%
x_best, fx_best = hill_climber(obj_function, delta=0.1, n_iter=1000, x_init=50) # Solution is 20
print(x_best, fx_best)
# Out:
# [26.12332973] [-312.50483307]

# %% [markdown]
# **B. Implement in Python a gradient descent method including Wolfe conditions for step size control (use algorithm of point C) You can also compute the exact step size by minimizing f(x+td) for t in R^+.**

# %% [markdown]
# **C.**![image.png](attachment:image.png)

# %% [markdown]
# **D. Implement in Python a gradient descent method including Wolfe conditions for step size control (use algorithm of point C) You can also compute the exact step size by minimizing f(x+td) for t in R^+.**
